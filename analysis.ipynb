# %%
import polars as pl
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
matplotlib.rcParams.update({'font.size': 14})

# %% [markdown]
# ## Median inter-block time

# %%
time = pl.read_csv("results/export-BlockTime.csv", separator=",", try_parse_dates=True)
time = time.with_columns(pl.col("Date(UTC)").str.strptime(pl.Date, format="%m/%d/%Y").alias("dt_date"))
time
# Out:
# shape: (3_941, 4)
# ┌───────────┬───────────────┬───────┬────────────┐
# │ Date(UTC) ┆ UnixTimeStamp ┆ Value ┆ dt_date    │
# │ ---       ┆ ---           ┆ ---   ┆ ---        │
# │ str       ┆ i64           ┆ f64   ┆ date       │
# ╞═══════════╪═══════════════╪═══════╪════════════╡
# │ 7/30/2015 ┆ 1438214400    ┆ 4.46  ┆ 2015-07-30 │
# │ 7/31/2015 ┆ 1438300800    ┆ 12.58 ┆ 2015-07-31 │
# │ 8/1/2015  ┆ 1438387200    ┆ 16.34 ┆ 2015-08-01 │
# │ 8/2/2015  ┆ 1438473600    ┆ 16.12 ┆ 2015-08-02 │
# │ 8/3/2015  ┆ 1438560000    ┆ 16.37 ┆ 2015-08-03 │
# │ …         ┆ …             ┆ …     ┆ …          │
# │ 5/9/2026  ┆ 1778284800    ┆ 12.04 ┆ 2026-05-09 │
# │ 5/10/2026 ┆ 1778371200    ┆ 12.03 ┆ 2026-05-10 │
# │ 5/11/2026 ┆ 1778457600    ┆ 12.05 ┆ 2026-05-11 │
# │ 5/12/2026 ┆ 1778544000    ┆ 12.02 ┆ 2026-05-12 │
# │ 5/13/2026 ┆ 1778630400    ┆ 12.05 ┆ 2026-05-13 │
# └───────────┴───────────────┴───────┴────────────┘

# %%
start_date = pl.datetime(2025, 1, 1)
end_date = pl.datetime(2025, 12, 31)
avg_time = round(time.filter((pl.col("dt_date") >= start_date) & (pl.col("dt_date") <= end_date))['Value'].median())
print(avg_time)
# Out:
# 12

# %% [markdown]
# ## Deployment costs

# %%
gas = pl.read_csv("results/export-AvgGasPrice.csv", separator=",", try_parse_dates=True)
gas = gas.with_columns(pl.col("Date(UTC)").str.strptime(pl.Date, format="%m/%d/%Y").alias("dt_date"))
gas
# Out:
# shape: (3_918, 4)
# ┌───────────┬───────────────┬─────────────┬────────────┐
# │ Date(UTC) ┆ UnixTimeStamp ┆ Value (Wei) ┆ dt_date    │
# │ ---       ┆ ---           ┆ ---         ┆ ---        │
# │ str       ┆ i64           ┆ i64         ┆ date       │
# ╞═══════════╪═══════════════╪═════════════╪════════════╡
# │ 7/30/2015 ┆ 1438214400    ┆ 0           ┆ 2015-07-30 │
# │ 7/31/2015 ┆ 1438300800    ┆ 0           ┆ 2015-07-31 │
# │ 8/1/2015  ┆ 1438387200    ┆ 0           ┆ 2015-08-01 │
# │ 8/2/2015  ┆ 1438473600    ┆ 0           ┆ 2015-08-02 │
# │ 8/3/2015  ┆ 1438560000    ┆ 0           ┆ 2015-08-03 │
# │ …         ┆ …             ┆ …           ┆ …          │
# │ 4/16/2026 ┆ 1776297600    ┆ 770524214   ┆ 2026-04-16 │
# │ 4/17/2026 ┆ 1776384000    ┆ 1894369818  ┆ 2026-04-17 │
# │ 4/18/2026 ┆ 1776470400    ┆ 1826432633  ┆ 2026-04-18 │
# │ 4/19/2026 ┆ 1776556800    ┆ 2761692377  ┆ 2026-04-19 │
# │ 4/20/2026 ┆ 1776643200    ┆ 3294495825  ┆ 2026-04-20 │
# └───────────┴───────────────┴─────────────┴────────────┘

# %%
ether = pl.read_csv("results/export-EtherPrice.csv", separator=",", try_parse_dates=True)
ether = ether.with_columns(pl.col("Date(UTC)").str.strptime(pl.Date, format="%m/%d/%Y").alias("dt_date"))
ether
# Out:
# shape: (3_919, 4)
# ┌───────────┬───────────────┬─────────┬────────────┐
# │ Date(UTC) ┆ UnixTimeStamp ┆ Value   ┆ dt_date    │
# │ ---       ┆ ---           ┆ ---     ┆ ---        │
# │ str       ┆ i64           ┆ f64     ┆ date       │
# ╞═══════════╪═══════════════╪═════════╪════════════╡
# │ 7/30/2015 ┆ 1438214400    ┆ 0.0     ┆ 2015-07-30 │
# │ 7/31/2015 ┆ 1438300800    ┆ 0.0     ┆ 2015-07-31 │
# │ 8/1/2015  ┆ 1438387200    ┆ 0.0     ┆ 2015-08-01 │
# │ 8/2/2015  ┆ 1438473600    ┆ 0.0     ┆ 2015-08-02 │
# │ 8/3/2015  ┆ 1438560000    ┆ 0.0     ┆ 2015-08-03 │
# │ …         ┆ …             ┆ …       ┆ …          │
# │ 4/17/2026 ┆ 1776384000    ┆ 2419.96 ┆ 2026-04-17 │
# │ 4/18/2026 ┆ 1776470400    ┆ 2351.39 ┆ 2026-04-18 │
# │ 4/19/2026 ┆ 1776556800    ┆ 2263.9  ┆ 2026-04-19 │
# │ 4/20/2026 ┆ 1776643200    ┆ 2314.78 ┆ 2026-04-20 │
# │ 4/21/2026 ┆ 1776729600    ┆ 2328.4  ┆ 2026-04-21 │
# └───────────┴───────────────┴─────────┴────────────┘

# %%
start_date = pl.datetime(2025, 1, 1)
end_date = pl.datetime(2025, 12, 31)
avg_gas_price = round(gas.filter((pl.col("dt_date") >= start_date) & (pl.col("dt_date") <= end_date))['Value (Wei)'].mean())
avg_eth_price = round(ether.filter((pl.col("dt_date") >= start_date) & (pl.col("dt_date") <= end_date))['Value'].mean())

def gas2usd(x):
  return x * avg_gas_price * 1e-18 * avg_eth_price

def usd2gas(x):
  return x / (avg_gas_price * 1e-18 * avg_eth_price)

# %%
df = pl.read_csv("results/OracleVerifierDeployment.tsv", separator="\t")
df
# Out:
# shape: (10, 3)
# ┌─────┬───────┬──────────┐
# │ f   ┆ n_min ┆ gas_cost │
# │ --- ┆ ---   ┆ ---      │
# │ i64 ┆ i64   ┆ i64      │
# ╞═════╪═══════╪══════════╡
# │ 1   ┆ 4     ┆ 1855651  │
# │ 2   ┆ 7     ┆ 1924651  │
# │ 3   ┆ 10    ┆ 1993735  │
# │ 4   ┆ 13    ┆ 2062711  │
# │ 5   ┆ 16    ┆ 2131783  │
# │ 6   ┆ 19    ┆ 2200843  │
# │ 7   ┆ 22    ┆ 2269867  │
# │ 8   ┆ 25    ┆ 2338891  │
# │ 9   ┆ 28    ┆ 2407927  │
# │ 10  ┆ 31    ┆ 2476939  │
# └─────┴───────┴──────────┘

# %%
plt.figure(figsize=(3, 3))
plt.title('OracleVerifier deployment')
plt.plot(df['n_min'], df['gas_cost'], color="royalblue", marker = 'o')
plt.xlabel('N. of nodes')
plt.ylabel('Gas cost')

formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((6, 6))

ax = plt.gca()
plt.grid(which='major', linestyle='--', linewidth=0.5)
plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
ax.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax.yaxis.set_major_formatter(formatter)

secax = ax.secondary_yaxis('right', functions=(gas2usd, usd2gas))
secax.set_ylabel('USD cost')

plt.savefig("figures/oracleverifier-deployment.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %%
df = pl.read_csv("results/RoyaltyManagerDeployment.tsv", separator="\t").filter(pl.col("n_holders") <= 1000)
df
# Out:
# shape: (7, 2)
# ┌───────────┬──────────┐
# │ n_holders ┆ gas_cost │
# │ ---       ┆ ---      │
# │ i64       ┆ i64      │
# ╞═══════════╪══════════╡
# │ 1         ┆ 1191137  │
# │ 5         ┆ 1282637  │
# │ 10        ┆ 1397039  │
# │ 50        ┆ 2312123  │
# │ 100       ┆ 3456130  │
# │ 500       ┆ 12611330 │
# │ 1000      ┆ 24058633 │
# └───────────┴──────────┘

# %%
plt.figure(figsize=(3, 3))
plt.title('RoyaltyManager deployment')
plt.plot(df['n_holders'], df['gas_cost'], color="royalblue", marker = 'o')
plt.xlabel('N. of data contributors')
plt.ylabel('Gas cost')

formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((6, 6))

ax = plt.gca()
plt.grid(which='major', linestyle='--', linewidth=0.5)
plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
ax.set_yticks([5*1e6, 10*1e6, 15*1e6, 20*1e6, 25*1e6])
ax.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax.yaxis.set_major_formatter(formatter)
#ax.yaxis.set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, pos: f'{x/1e6:.0f}M'))
#ax.yaxis.set_major_locator(matplotlib.ticker.MultipleLocator(1e6))

secax = ax.secondary_yaxis('right', functions=(gas2usd, usd2gas))
secax.set_ylabel('USD cost')
secax.set_yticks([50, 100, 150, 200, 250, 300])

plt.savefig("figures/royaltymanager-deployment.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Transmit costs

# %%
df = pd.read_csv("results/transmit.tsv", sep="\t")
df
# Out:
#     num_nodes  report_size  gas_used  transmit_a  transmit_v  dist_rew  \
# 0           4           10    316403      284765      271608     83270
# 1           4           25    379241      345683      332434    118055
# 2           4           50    480482      443724      430319    176114
# 3           4          100    685694      642536      628811    292238
# 4           4          250   1302094     1239736     1224994    641080
# ..        ...          ...       ...         ...         ...       ...
# 65         31           50    745958      681324      667573    176114
# 66         31          100    951238      880168      866087    292238
# 67         31          250   1567721     1477463     1462333    641080
# 68         31          500   2597809     2475491     2458418   1224044
# 69         31         1000   4667340     4481070     4459378   2395832
#
#     rew_holders
# 0         39886
# 1         74671
# 2        132730
# 3        248854
# 4        597696
# ..          ...
# 65       132730
# 66       248854
# 67       597696
# 68      1180660
# 69      2352448
#
# [70 rows x 7 columns]

# %%
gas_other = df['gas_used']-df['transmit_a']
gas_ta = df['transmit_a']-df['transmit_v']
gas_tv = df['transmit_v']-df['dist_rew']
gas_dr = df['dist_rew']-df['rew_holders']
gas_rh = df['rew_holders']
transmit_gas = pd.DataFrame({
    'num_nodes':df['num_nodes'],
    'report_size':df['report_size'],
    'gas_other':gas_other,
    'gas_ta':gas_ta,
    'gas_tv':gas_tv,
    'gas_dr':gas_dr,
    'gas_rh':gas_rh
})
transmit_gas
# Out:
#     num_nodes  report_size  gas_other  gas_ta   gas_tv  gas_dr   gas_rh
# 0           4           10      31638   13157   188338   43384    39886
# 1           4           25      33558   13249   214379   43384    74671
# 2           4           50      36758   13405   254205   43384   132730
# 3           4          100      43158   13725   336573   43384   248854
# 4           4          250      62358   14742   583914   43384   597696
# ..        ...          ...        ...     ...      ...     ...      ...
# 65         31           50      64634   13751   491459   43384   132730
# 66         31          100      71070   14081   573849   43384   248854
# 67         31          250      90258   15130   821253   43384   597696
# 68         31          500     122318   17073  1234374   43384  1180660
# 69         31         1000     186270   21692  2063546   43384  2352448
#
# [70 rows x 7 columns]

# %%
tgf = transmit_gas[transmit_gas['report_size'] == 1000].sort_values('num_nodes')
tgf
# Out:
#     num_nodes  report_size  gas_other  gas_ta   gas_tv  gas_dr   gas_rh
# 6           4         1000     158370   21147  1825890   43384  2352448
# 13          7         1000     161466   21207  1847256   43384  2352448
# 20         10         1000     164562   21267  1869882   43384  2352448
# 27         13         1000     167634   21327  1893768   43384  2352448
# 34         16         1000     170754   21388  1918914   43384  2352448
# 41         19         1000     173850   21448  1945320   43384  2352448
# 48         22         1000     176958   21509  1972986   43384  2352448
# 55         25         1000     180066   21570  2001912   43384  2352448
# 62         28         1000     183174   21631  2032099   43384  2352448
# 69         31         1000     186270   21692  2063546   43384  2352448

# %%
report_sizes = [10, 100, 1000]
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((6, 6))
for report_size in report_sizes:
    tgf = transmit_gas[transmit_gas['report_size'] == report_size].sort_values('num_nodes')
    plt.figure(figsize=(3, 3))
    plt.title(f"Transmit gas breakdown\n(report size = {report_size})")
    plt.xlabel('N. of nodes')
    plt.ylabel('Gas cost')
    plt.stackplot(
        tgf['num_nodes'],
        tgf['gas_other'],
        tgf['gas_ta'],
        tgf['gas_tv'],
        tgf['gas_dr'],
        tgf['gas_rh'],
        labels=['Other', 'transmit (aggr.)', 'transmit (verif.)', 'distributeRewards', 'rewardHolders'],
        colors=['lightgray', '#06C2AC', 'royalblue', 'gold', 'salmon']
        #alpha=0.8
    )
    ax = plt.gca()
    plt.grid(which='major', linestyle='--', linewidth=0.5)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    ax.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax.yaxis.set_major_formatter(formatter)
    secax = ax.secondary_yaxis('right', functions=(gas2usd, usd2gas))
    secax.set_ylabel('USD cost')
    if report_size in [10, 100]:
        plt.yticks([i * 1e5 for i in np.arange(0, 10+2, 2)])
    if report_size in [1000]:
        plt.yticks([i * 1e6 for i in np.arange(0, 5+1)])
        plt.legend(loc='center left', bbox_to_anchor=(1.3, 0.5))
    plt.savefig(f"figures/transmit-breakdown-{report_size}.pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
fig = plt.figure(figsize=(3, 3))
ax1 = fig.add_subplot()
ax1.set_title('Transmit gas costs')
ax1.set_xlabel('N. of nodes')
ax1.set_ylabel('Gas cost')
sns.lineplot(data=df, x="num_nodes", y="gas_used", hue=df["report_size"].astype(str), palette="rocket_r", marker="o", ax=ax1)
ax1.set_yticks([i * 1e6 for i in np.arange(0, 5+1)])
ax1.legend(title="Report size", loc='center left', bbox_to_anchor=(1.3, 0.5))
#
plt.grid(which='major', linestyle='--', linewidth=0.5)
plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
ax1.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax1.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax1.yaxis.set_major_formatter(formatter)
secax = ax1.secondary_yaxis('right', functions=(gas2usd, usd2gas))
secax.set_ylabel('USD cost')
secax.set_yticks([10, 20, 30, 40, 50])
plt.savefig("figures/transmit.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Model execution time

# %%
df_a = pd.read_csv("results/attribution_runs.tsv", sep="\t")
df_g = pd.read_csv("results/generation_runs.tsv", sep="\t")

runs = [f"run_{i+1}" for i in range(0, 15)]

df_a["mean"] = df_a[runs].mean(axis=1)
df_a["std"] = df_a[runs].std(axis=1)

df_g["mean"] = df_g[runs].mean(axis=1)
df_g["std"] = df_g[runs].std(axis=1)

# %%
fig = plt.figure(figsize=(6, 3))
ax1 = fig.add_subplot()
ax1.set_title('Model execution time')
ax1.set_xlabel('Output size (tokens)')
ax1.set_ylabel('Time (seconds)')
ax1.errorbar(df_g["size"], df_g["mean"], yerr=df_g["std"], color="red", fmt="o-", capsize=4, label="Generation")
ax1.errorbar(df_a["size"], df_a["mean"], yerr=df_a["std"], color="royalblue", fmt="o-", capsize=4, label="Attribution")
ax1.set_xscale('log')
ax1.legend()
plt.grid(which='major', linestyle='--', linewidth=0.5)
plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
#ax1.xaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
ax1.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
plt.savefig("figures/model-execution-time.pdf", format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Latency evaluation

# %%
nodes = [4, 7, 10, 13, 16]
sizes = [300, 3000, 30000]
df = dict()
for n in nodes:
    f = (n - 1) // 3
    for s in sizes:
        df[(str(n), "0", str(s))] = pd.read_csv(f"results/benchmark_latest/benchmark_results_n={n}_f=0_q={s}.csv")
        df[(str(n), f"{f}a", str(s))] = pd.read_csv(f"results/benchmark_latest/benchmark_results_n={n}_f={f}a_q={s}.csv")
        df[(str(n), f"{f}t", str(s))] = pd.read_csv(f"results/benchmark_latest/benchmark_results_n={n}_f={f}t_q={s}.csv")

avgs = dict()
stds = dict()
for n in nodes:
    f = (n - 1) // 3
    for s in sizes:
        #threshold_nf = df[(str(n), "0", str(s))]['Total_Latency(ms)'].quantile(0.85)
        latency_nf = df[(str(n), "0", str(s))]['Total_Latency(ms)'][1:]
        #latency_nf = latency_nf[latency_nf <= threshold_nf]
        avgs[(str(n), "0", str(s))] = float(latency_nf.mean())
        stds[(str(n), "0", str(s))] = float(latency_nf.std())

        #threshold_fa = df[(str(n), f"{f}a", str(s))]['Total_Latency(ms)'].quantile(0.85)
        latency_fa = df[(str(n), f"{f}a", str(s))]['Total_Latency(ms)'][1:]
        #latency_fa = latency_fa[latency_fa <= threshold_fa]
        avgs[(str(n), f"{f}a", str(s))] = float(latency_fa.mean())
        stds[(str(n), f"{f}a", str(s))] = float(latency_fa.std())

        #threshold_ft = df[(str(n), f"{f}t", str(s))]['Total_Latency(ms)'].quantile(0.85)
        latency_ft = df[(str(n), f"{f}t", str(s))]['Total_Latency(ms)'][1:]
        #latency_ft = latency_ft[latency_ft <= threshold_ft]
        avgs[(str(n), f"{f}t", str(s))] = float(latency_ft.mean())
        stds[(str(n), f"{f}t", str(s))] = float(latency_ft.std())

# %%
nodes = [4, 7, 10, 13, 16]
sizes = [300, 3000, 30000]
latency = dict()
for s in sizes:
    latency[str(s)] = pd.DataFrame({
        'nodes': nodes, 
        'mean_n': [avgs[(str(n), "0", str(s))] for n in nodes],
        'std_n': [stds[(str(n), "0", str(s))] for n in nodes],
        'mean_ft': [avgs[(str(n), f"{(n-1)//3}t", str(s))] for n in nodes],
        'std_ft': [stds[(str(n), f"{(n-1)//3}t", str(s))] for n in nodes],
        'mean_fa': [avgs[(str(n), f"{(n-1)//3}a", str(s))] for n in nodes],
        'std_fa': [stds[(str(n), f"{(n-1)//3}a", str(s))] for n in nodes]
    })

# %%
sizes = [300, 3000, 30000]
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((5, 5))
for s in sizes:
    # Data
    nodes = latency[str(s)]['nodes']
    # Positions
    x = np.arange(len(nodes))
    width = 0.25
    # Plot
    plt.figure(figsize=(3, 3))
    plt.title(' ' + str(s) + ' tokens ')
    plt.xlabel('N. of nodes')
    plt.ylabel('Latency (ms)')
    plt.bar(x - width, latency[str(s)]['mean_n'], width, yerr=latency[str(s)]['std_n'], capsize=2, color="forestgreen", label='No faulty')
    plt.bar(x, latency[str(s)]['mean_fa'], width, yerr=latency[str(s)]['std_fa'], capsize=2, color="#FF796C", label='Max. faulty (alter)')
    plt.bar(x + width, latency[str(s)]['mean_ft'], width, yerr=latency[str(s)]['std_ft'], capsize=2, color="#C20078", label='Max. faulty (timeout)')
    plt.xticks(x, nodes)
    plt.yticks([i*10**4 for i in range(0, 30, 4)])
    plt.grid(which='major', linestyle='--', linewidth=0.5)
    plt.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    plt.gca().yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    plt.gca().yaxis.set_major_formatter(formatter)
    if s == 300:
        plt.legend(loc='upper left', fontsize=11, frameon=True)
        #plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.savefig(f"figures/latency-total-{s}.pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
# Phases
columns = ["OffChain_Storage(ms)", "OnChain_RequestTx(ms)", "OnChain_ApprovalTx(ms)", "OCR_Consensus_And_FulfillmentTx(ms)"]
labels = ["Off-chain storage", "On-chain request", "On-chain approval", "Consensus & transmission"]
colors = ["slateblue", "violet", "lightseagreen", "orange"]
sizes = [300, 3000, 30000]
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))

for s in sizes:
    means_4 = df["4", "0", str(s)][columns][1:].mean().to_list()
    stds_4 = df["4", "0", str(s)][columns][1:].std().to_list()
    means_7 = df["7", "0", str(s)][columns][1:].mean().to_list()
    stds_7  = df["7", "0", str(s)][columns][1:].std().to_list()
    means_10 = df["10", "0", str(s)][columns][1:].mean().to_list()
    stds_10  = df["10", "0", str(s)][columns][1:].std().to_list()
    means_13 = df["13", "0", str(s)][columns][1:].mean().to_list()
    stds_13  = df["13", "0", str(s)][columns][1:].std().to_list()
    means_16 = df["16", "0", str(s)][columns][1:].mean().to_list()
    stds_16  = df["16", "0", str(s)][columns][1:].std().to_list()

    group_x = np.arange(5)
    # Bar width and offsets (4 bars per group)
    width = 0.2
    offsets = np.array([-1.5, -0.5, 0.5, 1.5]) * width

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(3, 5), layout='constrained')
    fig.suptitle(f"{s} tokens\nNo faulty")
    # Full version
    for i in range(4):
        ax1.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    ax1.set_ylim(bottom=0)
    ax1.set_xticks(group_x)
    ax1.set_xticklabels(['4', '7', '10', '13', '16'])
    ax1.set_ylabel("Latency (ms)")
    ax1.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax1.yaxis.set_major_formatter(formatter)
    ax1.grid(which='major', linestyle='--', linewidth=0.5)
    ax1.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    if s in [300, 3000]:
        ax1.set_yticks([i*(10**4) for i in range(0, 10+2, 2)])
    else:
        ax1.set_yticks([i*(10**4) for i in range(0, 20, 4)])
    
    #if s == 300:
    #    fig.canvas.draw()
    #    legend = ax1.legend(loc='upper left', frameon=False, bbox_to_anchor=(-4, 0.5))
    #    bbox = legend.get_window_extent()
    #    bbox = bbox.transformed(fig.dpi_scale_trans.inverted())
    #    fig.savefig("legend.pdf", bbox_inches=bbox)

    # Zoomed-in version
    for i in range(4):
        ax2.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    ax2.set_xticks(group_x)
    ax2.set_xticklabels(['4', '7', '10', '13', '16'])
    ax2.set_ylim(bottom=0, top=40)
    ax2.set_xlabel("N. of nodes")
    ax2.set_ylabel("Latency (ms)")
    ax2.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax2.grid(which='major', linestyle='--', linewidth=0.5)
    ax2.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    plt.savefig(f"figures/latency-breakdown-nf-{s}.pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
# Phases
columns = ["OffChain_Storage(ms)", "OnChain_RequestTx(ms)", "OnChain_ApprovalTx(ms)", "OCR_Consensus_And_FulfillmentTx(ms)"]
labels = ["Off-chain\nstorage", "On-chain\nrequest", "On-chain\napproval", "Consensus &\ntransmission"]
colors = ["slateblue", "violet", "lightseagreen", "orange"]
sizes = [300, 3000, 30000]
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))

for s in sizes:
    means_4 = df["4", "1a", str(s)][columns][1:].mean().to_list()
    stds_4 = df["4", "1a", str(s)][columns][1:].std().to_list()
    means_7 = df["7", "2a", str(s)][columns][1:].mean().to_list()
    stds_7  = df["7", "2a", str(s)][columns][1:].std().to_list()
    means_10 = df["10", "3a", str(s)][columns][1:].mean().to_list()
    stds_10  = df["10", "3a", str(s)][columns][1:].std().to_list()
    means_13 = df["13", "4a", str(s)][columns][1:].mean().to_list()
    stds_13  = df["13", "4a", str(s)][columns][1:].std().to_list()
    means_16 = df["16", "5a", str(s)][columns][1:].mean().to_list()
    stds_16  = df["16", "5a", str(s)][columns][1:].std().to_list()

    group_x = np.arange(5)
    # Bar width and offsets (4 bars per group)
    width = 0.2
    offsets = np.array([-1.5, -0.5, 0.5, 1.5]) * width

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(3, 5), layout='constrained')
    fig.suptitle(f"{s} tokens\nMax. faulty alter")
    # Full version
    for i in range(4):
        ax1.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    ax1.set_ylim(bottom=0)
    ax1.set_xticks(group_x)
    ax1.set_xticklabels(['4', '7', '10', '13', '16'])
    ax1.set_ylabel("Latency (ms)")
    ax1.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax1.yaxis.set_major_formatter(formatter)
    ax1.grid(which='major', linestyle='--', linewidth=0.5)
    ax1.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    if s in [300, 3000]:
        ax1.set_yticks([i*(10**4) for i in range(0, 8+2, 2)])
    else:
        ax1.set_yticks([i*(10**4) for i in range(0, 20, 4)])

    # Zoomed-in version
    for i in range(4):
        ax2.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    ax2.set_xticks(group_x)
    ax2.set_xticklabels(['4', '7', '10', '13', '16'])
    ax2.set_ylim(bottom=0, top=40)
    ax2.set_xlabel("N. of nodes")
    ax2.set_ylabel("Latency (ms)")
    ax2.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax2.grid(which='major', linestyle='--', linewidth=0.5)
    ax2.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    plt.savefig(f"figures/latency-breakdown-fa-{s}.pdf", format='pdf', bbox_inches='tight')
    plt.show()

# %%
# Phases
columns = ["OffChain_Storage(ms)", "OnChain_RequestTx(ms)", "OnChain_ApprovalTx(ms)", "OCR_Consensus_And_FulfillmentTx(ms)"]
labels = ["Off-chain\nstorage", "On-chain\nrequest", "On-chain\napproval", "Consensus &\ntransmission"]
colors = ["slateblue", "violet", "lightseagreen", "orange"]
sizes = [300, 3000, 30000]
formatter = matplotlib.ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((4, 4))

for s in sizes:
    means_4 = df["4", "1t", str(s)][columns][1:].mean().to_list()
    stds_4 = df["4", "1t", str(s)][columns][1:].std().to_list()
    means_7 = df["7", "2t", str(s)][columns][1:].mean().to_list()
    stds_7  = df["7", "2t", str(s)][columns][1:].std().to_list()
    means_10 = df["10", "3t", str(s)][columns][1:].mean().to_list()
    stds_10  = df["10", "3t", str(s)][columns][1:].std().to_list()
    means_13 = df["13", "4t", str(s)][columns][1:].mean().to_list()
    stds_13  = df["13", "4t", str(s)][columns][1:].std().to_list()
    means_16 = df["16", "5t", str(s)][columns][1:].mean().to_list()
    stds_16  = df["16", "5t", str(s)][columns][1:].std().to_list()

    group_x = np.arange(5)
    # Bar width and offsets (4 bars per group)
    width = 0.2
    offsets = np.array([-1.5, -0.5, 0.5, 1.5]) * width

    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(3, 5), layout='constrained')
    fig.suptitle(f"{s} tokens\nMax. faulty timeout")
    # Full version
    for i in range(4):
        ax1.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    ax1.set_ylim(bottom=0)
    ax1.set_xticks(group_x)
    ax1.set_xticklabels(['4', '7', '10', '13', '16'])
    #ax1.set_xlabel("N. of nodes")
    ax1.set_ylabel("Latency (ms)")
    ax1.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax1.yaxis.set_major_formatter(formatter)
    ax1.grid(which='major', linestyle='--', linewidth=0.5)
    ax1.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    # Zoomed-in version
    for i in range(4):
        ax2.bar(group_x + offsets[i],
                [means_4[i], means_7[i], means_10[i], means_13[i], means_16[i]],
                width,
                yerr=[stds_4[i], stds_7[i], stds_10[i], stds_13[i], stds_16[i]],
                capsize=2,
                label=labels[i], color=colors[i])
    if s in [300, 3000]:
        ax1.set_yticks([i*(10**4) for i in range(0, 12+4, 4)])
    else:
        ax1.set_yticks([i*(10**4) for i in range(0, 24+8, 8)])
    ax2.set_xticks(group_x)
    ax2.set_xticklabels(['4', '7', '10', '13', '16'])
    ax2.set_ylim(bottom=0, top=40)
    ax2.set_xlabel("N. of nodes")
    ax2.set_ylabel("Latency (ms)")
    ax2.yaxis.set_minor_locator(matplotlib.ticker.AutoMinorLocator(2))
    ax2.grid(which='major', linestyle='--', linewidth=0.5)
    ax2.grid(which='minor', linestyle='--', linewidth=0.5, alpha=0.2)
    plt.savefig(f"figures/latency-breakdown-ft-{s}.pdf", format='pdf', bbox_inches='tight')
    plt.show()
